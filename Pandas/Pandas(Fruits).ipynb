# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/mydata/fruits.csv")
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 4     may     77   67.0     90     195    90.0      55    574     95.7
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 11    dec     65   89.0     43      43    76.0      77    393     65.5

# %%
#display top 5 rows
df.head()
# Out:
#   months  apple  mango grapes  orange  banana  cherry  Total  Average
# 0    jan     56   23.0     53      11   200.0      67    410     68.3
# 1    feb     77   56.0     54      67    89.0      54    397     66.2
# 2    mar     89   75.0     ab      89     NaN      67    441     73.5
# 3    apr     90   44.0     78      55    78.0      89    434     72.3
# 4    may     77   67.0     90     195    90.0      55    574     95.7

# %%
#display last 5 rows
df.tail()
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 11    dec     65   89.0     43      43    76.0      77    393     65.5

# %%
#dispay count of values
df.size
# Out:
# 108

# %%
#Generate descriptive statistics.
df.describe()
# Out:
#            apple       mango      orange    banana     cherry       Total  \
# count  12.000000   11.000000   12.000000   10.0000  12.000000   12.000000
# mean   77.250000   66.909091   71.750000   94.1000  64.166667  445.416667
# std    11.103849   29.666326   45.493506   41.6692  14.671143   60.182236
# min    56.000000   23.000000   11.000000   54.0000  43.000000  385.000000
# 25%    73.250000   54.000000   44.000000   69.2500  54.000000  406.750000
# 50%    77.000000   67.000000   61.500000   83.5000  61.000000  426.500000
# 75%    89.000000   71.000000   89.000000   97.5000  69.500000  460.000000
# max    90.000000  140.000000  195.000000  200.0000  89.000000  574.000000
#
#          Average
# count  12.000000
# mean   74.241667
# std    10.044217
# min    64.200000
# 25%    67.775000
# 50%    71.050000
# 75%    76.700000
# max    95.700000

# %%
#displays the count of rows and columns in the data frame
df.shape
# Out:
# (12, 9)

# %%
#gives the column details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   months   12 non-null     object
#  1   apple    12 non-null     int64
#  2   mango    11 non-null     float64
#  3   grapes   12 non-null     object
#  4   orange   12 non-null     int64
#  5   banana   10 non-null     float64
#  6   cherry   12 non-null     int64
#  7   Total    12 non-null     int64
#  8   Average  12 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 996.0+ bytes

# %%
df.memory_usage()
# Out:
# Index      132
# months      96
# apple       96
# mango       96
# grapes      96
# orange      96
# banana      96
# cherry      96
# Total       96
# Average     96
# dtype: int64

# %%
df.sort_values('Total')
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 4     may     77   67.0     90     195    90.0      55    574     95.7
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 11    dec     65   89.0     43      43    76.0      77    393     65.5

# %%
df.sort_values('Total',inplace=True)
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 11    dec     65   89.0     43      43    76.0      77    393     65.5
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 4     may     77   67.0     90     195    90.0      55    574     95.7

# %%
df.sort_values('Total',ascending=False,inplace=True)
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 4     may     77   67.0     90     195    90.0      55    574     95.7
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 11    dec     65   89.0     43      43    76.0      77    393     65.5
# 5     jun     65    NaN     44      44   100.0      43    385     64.2

# %%
df.sort_values('Total',ascending=True,inplace=True)
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 11    dec     65   89.0     43      43    76.0      77    393     65.5
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 4     may     77   67.0     90     195    90.0      55    574     95.7

# %%
df.sort_index(inplace=True)
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 4     may     77   67.0     90     195    90.0      55    574     95.7
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 11    dec     65   89.0     43      43    76.0      77    393     65.5

# %%
df.sort_index(ascending=False,inplace=True)
print(df)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 11    dec     65   89.0     43      43    76.0      77    393     65.5
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 8     sep     89  140.0     55      56   120.0      54    514     85.7
# 7     aug     76   67.0     89      44     NaN      54    419     69.8
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 4     may     77   67.0     90     195    90.0      55    574     95.7
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 2     mar     89   75.0     ab      89     NaN      67    441     73.5
# 1     feb     77   56.0     54      67    89.0      54    397     66.2
# 0     jan     56   23.0     53      11   200.0      67    410     68.3

# %%
x=df.sample(frac=0.5)
print(x)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 4     may     77   67.0     90     195    90.0      55    574     95.7
# 5     jun     65    NaN     44      44   100.0      43    385     64.2
# 0     jan     56   23.0     53      11   200.0      67    410     68.3
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 3     apr     90   44.0     78      55    78.0      89    434     72.3
# 11    dec     65   89.0     43      43    76.0      77    393     65.5

# %%
x=df.sample(n=5)
print(x)
# Out:
#   months  apple  mango grapes  orange  banana  cherry  Total  Average
# 4    may     77   67.0     90     195    90.0      55    574     95.7
# 5    jun     65    NaN     44      44   100.0      43    385     64.2
# 7    aug     76   67.0     89      44     NaN      54    419     69.8
# 1    feb     77   56.0     54      67    89.0      54    397     66.2
# 8    sep     89  140.0     55      56   120.0      54    514     85.7

# %%
x=df.nlargest(5,'banana')
print(x)
# Out:
#   months  apple  mango grapes  orange  banana  cherry  Total  Average
# 0    jan     56   23.0     53      11   200.0      67    410     68.3
# 8    sep     89  140.0     55      56   120.0      54    514     85.7
# 5    jun     65    NaN     44      44   100.0      43    385     64.2
# 4    may     77   67.0     90     195    90.0      55    574     95.7
# 1    feb     77   56.0     54      67    89.0      54    397     66.2

# %%
x=df.nsmallest(5,'banana')
print(x)
# Out:
#    months  apple  mango grapes  orange  banana  cherry  Total  Average
# 9     oct     90   54.0     67      78    54.0      67    410     68.3
# 10    nov     77   67.0     88      89    67.0      54    442     73.7
# 6     jul     76   54.0    150      90    67.0      89    526     87.7
# 11    dec     65   89.0     43      43    76.0      77    393     65.5
# 3     apr     90   44.0     78      55    78.0      89    434     72.3

# %%
df.isnull()
# Out:
#     months  apple  mango  grapes  orange  banana  cherry  Total  Average
# 11   False  False  False   False   False   False   False  False    False
# 10   False  False  False   False   False   False   False  False    False
# 9    False  False  False   False   False   False   False  False    False
# 8    False  False  False   False   False   False   False  False    False
# 7    False  False  False   False   False    True   False  False    False
# 6    False  False  False   False   False   False   False  False    False
# 5    False  False   True   False   False   False   False  False    False
# 4    False  False  False   False   False   False   False  False    False
# 3    False  False  False   False   False   False   False  False    False
# 2    False  False  False   False   False    True   False  False    False
# 1    False  False  False   False   False   False   False  False    False
# 0    False  False  False   False   False   False   False  False    False

# %%
df['banana'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['mango'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['grapes'].apply(lambda x: pd.to_numeric(x, errors='coerce')).isnull().sum()
# Out:
# np.int64(1)

# %%
df.isnull().sum()
# Out:
# months     0
# apple      0
# mango      1
# grapes     0
# orange     0
# banana     2
# cherry     0
# Total      0
# Average    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# months     False
# apple      False
# mango       True
# grapes     False
# orange     False
# banana      True
# cherry     False
# Total      False
# Average    False
# dtype: bool

# %%
df['banana'] = df['banana'].fillna(df['banana'].mean())
df['banana']
# Out:
# 11     76.0
# 10     67.0
# 9      54.0
# 8     120.0
# 7      94.1
# 6      67.0
# 5     100.0
# 4      90.0
# 3      78.0
# 2      94.1
# 1      89.0
# 0     200.0
# Name: banana, dtype: float64

# %%
df['mango'] = df['mango'].fillna(df['mango'].mean())
df
# Out:
#    months  apple       mango grapes  orange  banana  cherry  Total  Average
# 11    dec     65   89.000000     43      43    76.0      77    393     65.5
# 10    nov     77   67.000000     88      89    67.0      54    442     73.7
# 9     oct     90   54.000000     67      78    54.0      67    410     68.3
# 8     sep     89  140.000000     55      56   120.0      54    514     85.7
# 7     aug     76   67.000000     89      44    94.1      54    419     69.8
# 6     jul     76   54.000000    150      90    67.0      89    526     87.7
# 5     jun     65   66.909091     44      44   100.0      43    385     64.2
# 4     may     77   67.000000     90     195    90.0      55    574     95.7
# 3     apr     90   44.000000     78      55    78.0      89    434     72.3
# 2     mar     89   75.000000     ab      89    94.1      67    441     73.5
# 1     feb     77   56.000000     54      67    89.0      54    397     66.2
# ...

# %%
df['grapes'] = pd.to_numeric(df['grapes'], errors='coerce')
if (df['grapes'] == "ab").any():
 df['grapes'] = df['grapes'].fillna(df['grapes'].mean())
df
# Out:
#    months  apple       mango  grapes  orange  banana  cherry  Total  Average
# 11    dec     65   89.000000    43.0      43    76.0      77    393     65.5
# 10    nov     77   67.000000    88.0      89    67.0      54    442     73.7
# 9     oct     90   54.000000    67.0      78    54.0      67    410     68.3
# 8     sep     89  140.000000    55.0      56   120.0      54    514     85.7
# 7     aug     76   67.000000    89.0      44    94.1      54    419     69.8
# 6     jul     76   54.000000   150.0      90    67.0      89    526     87.7
# 5     jun     65   66.909091    44.0      44   100.0      43    385     64.2
# 4     may     77   67.000000    90.0     195    90.0      55    574     95.7
# 3     apr     90   44.000000    78.0      55    78.0      89    434     72.3
# 2     mar     89   75.000000     NaN      89    94.1      67    441     73.5
# 1     feb     77   56.000000    54.0      67    89.0      54    397     66.2
# ...

# %%
df.drop(columns=['mango'])
print(df)
# Out:
#    months  apple       mango  grapes  orange  banana  cherry  Total  Average
# 11    dec     65   89.000000    43.0      43    76.0      77    393     65.5
# 10    nov     77   67.000000    88.0      89    67.0      54    442     73.7
# 9     oct     90   54.000000    67.0      78    54.0      67    410     68.3
# 8     sep     89  140.000000    55.0      56   120.0      54    514     85.7
# 7     aug     76   67.000000    89.0      44    94.1      54    419     69.8
# 6     jul     76   54.000000   150.0      90    67.0      89    526     87.7
# 5     jun     65   66.909091    44.0      44   100.0      43    385     64.2
# 4     may     77   67.000000    90.0     195    90.0      55    574     95.7
# 3     apr     90   44.000000    78.0      55    78.0      89    434     72.3
# 2     mar     89   75.000000     NaN      89    94.1      67    441     73.5
# 1     feb     77   56.000000    54.0      67    89.0      54    397     66.2
# ...

# %%
df.drop(columns=['mango'],inplace=True)
print(df)
# Out:
#    months  apple  grapes  orange  banana  cherry  Total  Average
# 11    dec     65    43.0      43    76.0      77    393     65.5
# 10    nov     77    88.0      89    67.0      54    442     73.7
# 9     oct     90    67.0      78    54.0      67    410     68.3
# 8     sep     89    55.0      56   120.0      54    514     85.7
# 7     aug     76    89.0      44    94.1      54    419     69.8
# 6     jul     76   150.0      90    67.0      89    526     87.7
# 5     jun     65    44.0      44   100.0      43    385     64.2
# 4     may     77    90.0     195    90.0      55    574     95.7
# 3     apr     90    78.0      55    78.0      89    434     72.3
# 2     mar     89     NaN      89    94.1      67    441     73.5
# 1     feb     77    54.0      67    89.0      54    397     66.2
# 0     jan     56    53.0      11   200.0      67    410     68.3

# %%
df.drop(0)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2483/2189458777.py in <cell line: 0>()
# ----> 1 df.drop(0)
#       2 print(df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.drop(0,inplace=True)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2483/3763852444.py in <cell line: 0>()
# ----> 1 df.drop(0,inplace=True)
#       2 print(df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.reset_index(drop=True,inplace=True)
print(df)
# Out:
#    months  apple  grapes  orange  banana  cherry  Total  Average
# 0     dec     65    43.0      43    76.0      77    393     65.5
# 1     nov     77    88.0      89    67.0      54    442     73.7
# 2     oct     90    67.0      78    54.0      67    410     68.3
# 3     sep     89    55.0      56   120.0      54    514     85.7
# 4     aug     76    89.0      44    94.1      54    419     69.8
# 5     jul     76   150.0      90    67.0      89    526     87.7
# 6     jun     65    44.0      44   100.0      43    385     64.2
# 7     may     77    90.0     195    90.0      55    574     95.7
# 8     apr     90    78.0      55    78.0      89    434     72.3
# 9     mar     89     NaN      89    94.1      67    441     73.5
# 10    feb     77    54.0      67    89.0      54    397     66.2

# %%
df['cherry'].unique()
# Out:
# array([54, 67, 89, 43, 55])

# %%
df.rename(columns = {'months':'m'},inplace=True)
print(df)
# Out:
#       m  apple  grapes  orange  banana  cherry  Total  Average
# 0   dec     65    43.0      43    76.0      77    393     65.5
# 1   nov     77    88.0      89    67.0      54    442     73.7
# 2   oct     90    67.0      78    54.0      67    410     68.3
# 3   sep     89    55.0      56   120.0      54    514     85.7
# 4   aug     76    89.0      44    94.1      54    419     69.8
# 5   jul     76   150.0      90    67.0      89    526     87.7
# 6   jun     65    44.0      44   100.0      43    385     64.2
# 7   may     77    90.0     195    90.0      55    574     95.7
# 8   apr     90    78.0      55    78.0      89    434     72.3
# 9   mar     89     NaN      89    94.1      67    441     73.5
# 10  feb     77    54.0      67    89.0      54    397     66.2

# %%
df['m'].unique()
# Out:
# array(['dec', 'nov', 'oct', 'sep', 'aug', 'jul', 'jun', 'may', 'apr',
#        'mar', 'feb'], dtype=object)

# %%
x = df[df['Total'] > 500]
print(x)
# Out:
#      m  apple  grapes  orange  banana  cherry  Total  Average
# 3  sep     89    55.0      56   120.0      54    514     85.7
# 5  jul     76   150.0      90    67.0      89    526     87.7
# 7  may     77    90.0     195    90.0      55    574     95.7

# %%
filtered_df = df[df['Total'] > 500]
filtered_df
# Out:
#      m  apple  grapes  orange  banana  cherry  Total  Average
# 3  sep     89    55.0      56   120.0      54    514     85.7
# 5  jul     76   150.0      90    67.0      89    526     87.7
# 7  may     77    90.0     195    90.0      55    574     95.7

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.pairplot(df)
